# %% [markdown]
# # Stroma Vision Challange için oluşturulmuş Prediction Notebook dosyası
#
# # Author: Bilge Kaan Gürgen

# %%
# !nvidia-smi
# Out:
# Thu Feb 23 17:46:48 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P0    32W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/SkalskiP/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 579, done.
# remote: Total 579 (delta 0), reused 0 (delta 0), pack-reused 579
# Receiving objects: 100% (579/579), 38.17 MiB | 23.35 MiB/s, done.
# Resolving deltas: 100% (287/287), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Drive içerisinden `pred.py` , `sort.py` , `requirements.txt` , `requirements_gpu.txt` dosyalarını yolov7 içerisine atmamız gerekiyor.
#
# ## Link: https://drive.google.com/file/d/1vWEsg5wmFAy4PqPwugHecPzBAVgnpn0B/view?usp=sharing
#
# # İndirin ve sonra colab de oluşan yolov7 içerisine atın.

# %% [markdown]
# ## Dosyaları yolov7 içerisine attıktan sonra bu aşamaları ilerletebiliriz.

# %%
# %cd /content/yolov7
# !pip install -r requirements.txt
# Out:
# /content/yolov7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 KB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.0 MB/s eta 0:00:00
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110474 sha256=62eaaaddea38bffe22ff9cb93d1fd8ab4305c3a1697ede3542c3ecb88cb90854
#   Stored in directory: /root/.cache/pip/wheels/fe/f6/cb/40331472edf4fd399b8cad02973c6acbdf26898342928327fe
# Successfully built filterpy
# ...

# %%
# !pip install -r requirements_gpu.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu113
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 GB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 41.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.11.0+cu113 which is incompatible.
# torchaudio 0.13.1+cu116 requires torch==1.13.1, but you have torch 1.11.0+cu113 which is incompatible.
# ...

# %% [markdown]
# # Link : https://drive.google.com/file/d/1vjdGoTi0UGOjXEuRv3W6EqY0UJVcbay6/view?usp=sharing
#
# # Burada ki `best.pt` ağırlık dosyasını da yolov7 klasörü içerisine yüklüyoruz. Bu dosya eğitim sonrası çıkan en iyi değeri gösteren dosyadır.

# %% [markdown]
# # Test video'su için de link verdim kullanmak isterseniz.
# # Dosya adı testvid.mp4
# # Bu dosyayı yolov7 içine atabilirsiniz.
# # Link: https://drive.google.com/file/d/1XwTSxFsmSZ0yIxMYlK_NNBIICOhV1Bz4/view?usp=sharing

# %%
# !python pred.py --weights best.pt --conf 0.75 --img-size 640 --source testvid.mp4 --no-trace --track
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.75, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=True, nobbox=False, nolabel=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, seed=1, show_fps=False, show_track=False, source='testvid.mp4', thickness=2, track=True, unique_track_color=False, update=False, view_img=False, weights=['best.pt'])
# YOLOR 🚀 8e9f0b7 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15109.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# Burada conf 0.75 olarak ayarlandı çıktıalrı %75 doğruluk üzeri olanların görülmesi istediğim için böyle bir seçenek yaptım.

# %% [markdown]
# Buradan sonra çıktılar yolov7 içerisinde runs klasöründe kaçıncı exp yada exp1 exp2 numarası en son kaç ta iseniz ona göre içerisine atacaktır.

# %% [markdown]
# # Sonuç
#
# ### Video Sonucunu görebilirisniz.
#
# ### Link:https://drive.google.com/file/d/1BtbForG_GCb5M8spGb8GJssTC9nlwIwJ/view?usp=sharing
